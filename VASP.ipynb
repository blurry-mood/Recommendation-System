# %% [markdown]
# <a href="https://colab.research.google.com/github/blurry-mood/Recommendation-System/blob/main/VASP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First we need to import utils package and tensorflow with addons.

# %%
# !wget  https://raw.githubusercontent.com/zombak79/vasp/main/utils.py
# Out:
# --2022-01-04 15:41:57--  https://raw.githubusercontent.com/zombak79/vasp/main/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29134 (28K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]  28.45K  --.-KB/s    in 0.002s
#
# 2022-01-04 15:41:57 (15.6 MB/s) - ‘utils.py’ saved [29134/29134]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.4 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
from utils import *
import tensorflow as tf
import tensorflow_addons as tfa

set_seed(42)

# %% [markdown]
# Next, we define our model. Note that reparametrization trick is done manually - it can be done with tensorflow probability package, which is doing that by itself automatically.

# %%
class DiagonalToZero(tf.keras.constraints.Constraint):
    def __call__(self, w):
        """Set diagonal to zero"""
        q = tf.linalg.set_diag(w, tf.zeros(w.shape[0:-1]), name=None)
        return q

class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a basket."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim), stddev=1.)
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class VASP(Model):
    class Model(tf.keras.Model):
        def __init__(self, num_words, latent=1024, hidden=1024, items_sampling=1.):
            """
            num_words             nr of items in dataset (size of tokenizer)
            latent                size of latent space
            hidden                size of hidden layers
            items_sampling        Large items datatsets can be very gpu memory consuming in EASE layer.
                                  This coefficient reduces number of ease parametrs by taking only
                                  fraction of items sorted by popularity as input for model.
                                  Note: This coef should be somewhere around coverage@100 achieved by full
                                  size model.
                                  For ML20M this coef should be between 0.4888 (coverage@100 for full model)
                                  and 1.0
                                  For Netflix this coef should be between 0.7055 (coverage@100 for full
                                  model) and 1.0
            """
            super(VASP.Model, self).__init__()

            self.sampled_items = int(num_words * items_sampling)

            assert self.sampled_items > 0
            assert self.sampled_items <= num_words

            self.s = self.sampled_items < num_words

            # ************* ENCODER ***********************
            self.encoder1 = tf.keras.layers.Dense(hidden)
            self.ln1 = tf.keras.layers.LayerNormalization()
            self.encoder2 = tf.keras.layers.Dense(hidden)
            self.ln2 = tf.keras.layers.LayerNormalization()
            self.encoder3 = tf.keras.layers.Dense(hidden)
            self.ln3 = tf.keras.layers.LayerNormalization()
            self.encoder4 = tf.keras.layers.Dense(hidden)
            self.ln4 = tf.keras.layers.LayerNormalization()
            self.encoder5 = tf.keras.layers.Dense(hidden)
            self.ln5 = tf.keras.layers.LayerNormalization()
            self.encoder6 = tf.keras.layers.Dense(hidden)
            self.ln6 = tf.keras.layers.LayerNormalization()
            self.encoder7 = tf.keras.layers.Dense(hidden)
            self.ln7 = tf.keras.layers.LayerNormalization()

            # ************* SAMPLING **********************
            self.dense_mean = tf.keras.layers.Dense(latent,
                                                    name="Mean")
            self.dense_log_var = tf.keras.layers.Dense(latent,
                                                       name="log_var")

            self.sampling = Sampling(name='Sampler')

            # ************* DECODER ***********************
            self.decoder1 = tf.keras.layers.Dense(hidden)
            self.dln1 = tf.keras.layers.LayerNormalization()
            self.decoder2 = tf.keras.layers.Dense(hidden)
            self.dln2 = tf.keras.layers.LayerNormalization()
            self.decoder3 = tf.keras.layers.Dense(hidden)
            self.dln3 = tf.keras.layers.LayerNormalization()
            self.decoder4 = tf.keras.layers.Dense(hidden)
            self.dln4 = tf.keras.layers.LayerNormalization()
            self.decoder5 = tf.keras.layers.Dense(hidden)
            self.dln5 = tf.keras.layers.LayerNormalization()

            self.decoder_resnet = tf.keras.layers.Dense(self.sampled_items,
                                                        activation='sigmoid',
                                                        name="DecoderR")
            self.decoder_latent = tf.keras.layers.Dense(self.sampled_items,
                                                        activation='sigmoid',
                                                        name="DecoderL")

            # ************* PARALLEL SHALLOW PATH *********

            self.ease = tf.keras.layers.Dense(
                self.sampled_items,
                activation='sigmoid',
                use_bias=False,
                kernel_constraint=DiagonalToZero(),  # critical to prevent learning simple identity
            )

        def call(self, x, training=None):
            sampling = self.s
            if sampling:
                sampled_x = x[:, :self.sampled_items]
                non_sampled = x[:, self.sampled_items:] * 0.
            else:
                sampled_x = x

            z_mean, z_log_var, z = self.encode(sampled_x)
            if training:
                d = self.decode(z)
                # Add KL divergence regularization loss.
                kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
                kl_loss = tf.reduce_mean(kl_loss)
                kl_loss *= -0.5
                self.add_loss(kl_loss)
                self.add_metric(kl_loss, name="kl_div")
            else:
                d = self.decode(z_mean)

            if sampling:
                d = tf.concat([d, non_sampled], axis=-1)

            ease = self.ease(sampled_x)

            if sampling:
                ease = tf.concat([ease, non_sampled], axis=-1)

            return d * ease

        def decode(self, x):
            e0 = x
            e1 = self.dln1(tf.keras.activations.swish(self.decoder1(e0)))
            e2 = self.dln2(tf.keras.activations.swish(self.decoder2(e1) + e1))
            e3 = self.dln3(tf.keras.activations.swish(self.decoder3(e2) + e1 + e2))
            e4 = self.dln4(tf.keras.activations.swish(self.decoder4(e3) + e1 + e2 + e3))
            e5 = self.dln5(tf.keras.activations.swish(self.decoder5(e4) + e1 + e2 + e3 + e4))

            dr = self.decoder_resnet(e5)
            dl = self.decoder_latent(x)

            return dr * dl

        def encode(self, x):
            e0 = x
            e1 = self.ln1(tf.keras.activations.swish(self.encoder1(e0)))
            e2 = self.ln2(tf.keras.activations.swish(self.encoder2(e1) + e1))
            e3 = self.ln3(tf.keras.activations.swish(self.encoder3(e2) + e1 + e2))
            e4 = self.ln4(tf.keras.activations.swish(self.encoder4(e3) + e1 + e2 + e3))
            e5 = self.ln5(tf.keras.activations.swish(self.encoder5(e4) + e1 + e2 + e3 + e4))
            e6 = self.ln6(tf.keras.activations.swish(self.encoder6(e5) + e1 + e2 + e3 + e4 + e5))
            e7 = self.ln7(tf.keras.activations.swish(self.encoder7(e6) + e1 + e2 + e3 + e4 + e5 + e6))

            z_mean = self.dense_mean(e7)
            z_log_var = self.dense_log_var(e7)
            z = self.sampling((z_mean, z_log_var))

            return z_mean, z_log_var, z

    def create_model(self, latent=2048, hidden=4096, ease_items_sampling=1., summary=False):
        self.model = VASP.Model(self.dataset.num_words, latent, hidden, ease_items_sampling)
        self.model(self.split.train_gen[0][0])
        if summary:
            self.model.summary()
        self.mc = MetricsCallback(self)

    def compile_model(self, lr=0.00002, fl_alpha=0.25, fl_gamma=2.0):
        """
        lr         learning rate of Nadam optimizer
        fl_alpha   alpha parameter of focal crossentropy
        fl_gamma   gamma parameter of focal crossentropy
        """
        self.model.compile(
            optimizer=tf.keras.optimizers.Nadam(lr),
            loss=lambda x, y: tfa.losses.sigmoid_focal_crossentropy(x, y, alpha=fl_alpha, gamma=fl_gamma),
            metrics=['mse', cosine_loss]
        )

    def train_model(self, epochs=150):
        self.model.fit(
            self.split.train_gen,
            validation_data=self.split.validation_gen,
            epochs=epochs,
            callbacks=[self.mc]
        )

# %% [markdown]
# Now, we can load previously preprocessed dataset. We also load pre-defined train/test/validation split.

# %%
d = '/content/drive/MyDrive/MovieLens/'
dataset = Data(d=d, pruning='u5')
dataset.splits = []
dataset.create_splits(1, 10000, shuffle=False, generators=False)
dataset.split.train_users = pd.read_json(d+"train_users.json").userid.apply(str).to_frame()
dataset.split.validation_users = pd.read_json(d+"val_users.json").userid.apply(str).to_frame()
dataset.split.test_users = pd.read_json(d+"test_users.json").userid.apply(str).to_frame()
dataset.split.generators()
# Out:
# Reading users_pu5
# Reading items_pu5
# Reading purchases_txt_pu5
# Reading items_sorted_pu5
# Reading users_sorted_pu5
# Read all in 4.297754287719727
# Tokenizer trained for 20721 items.
# Creating 1 splits of 10000 samples each.
# Creating split nr. 1
# SplitGenerator init done in 8.164264678955078 secs.
# SplitGenerator init done in 0.7009353637695312 secs.
# SplitGenerator init done in 0.7104215621948242 secs.
# Creating evaluator
# Creating test split evaluator with leave_random_20_pct_out method.
# Creating validation split evaluator with leave_random_20_pct_out method.

# %%
# open('/content/drive/MyDrive/MovieLens/toki.json',"w").write(dataset.toki.to_json())
json_string = open('/content/drive/MyDrive/MovieLens/toki.json').read()
dataset.toki = tf.keras.preprocessing.text.tokenizer_from_json(json_string)

# %% [markdown]
# Now we can create an instance of our model and train it.
#
# For validation during training we sample 80% of the user's interactions randomly as input for the model, and then we measure Recall@20, Recall@50 and NDCG@100 for predicted interactions against the remaining 20% of the user's interactions.
#
# This method can give different results for different seeds, but since it is used for validation during training only, it's good enough.

# %%
m = VASP(dataset.split, name="VASP_ML20_1")
m.create_model(latent=2048, hidden=4096, ease_items_sampling= 0.5)
m.model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  42438656
#
#  layer_normalization (LayerN  multiple                 8192
#  ormalization)
#
#  dense_1 (Dense)             multiple                  16781312
#
#  layer_normalization_1 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_2 (Dense)             multiple                  16781312
#
#  layer_normalization_2 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_3 (Dense)             multiple                  16781312
#
#  layer_normalization_3 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_4 (Dense)             multiple                  16781312
#
#  layer_normalization_4 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_5 (Dense)             multiple                  16781312
#
#  layer_normalization_5 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_6 (Dense)             multiple                  16781312
#
#  layer_normalization_6 (Laye  multiple                 8192
#  rNormalization)
#
#  Mean (Dense)                multiple                  8390656
#
#  log_var (Dense)             multiple                  8390656
#
#  Sampler (Sampling)          multiple                  0
#
#  dense_7 (Dense)             multiple                  8392704
#
#  layer_normalization_7 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_8 (Dense)             multiple                  16781312
#
#  layer_normalization_8 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_9 (Dense)             multiple                  16781312
#
#  layer_normalization_9 (Laye  multiple                 8192
#  rNormalization)
#
#  dense_10 (Dense)            multiple                  16781312
#
#  layer_normalization_10 (Lay  multiple                 8192
#  erNormalization)
#
#  dense_11 (Dense)            multiple                  16781312
#
#  layer_normalization_11 (Lay  multiple                 8192
#  erNormalization)
#
#  DecoderR (Dense)            multiple                  42444920
#
#  DecoderL (Dense)            multiple                  21227640
#
#  dense_12 (Dense)            multiple                  107329600
#
# =================================================================
# Total params: 406,526,256
# Trainable params: 406,526,256
# Non-trainable params: 0
# _________________________________________________________________

# %%
m.model.load_weights('/content/drive/MyDrive/MovieLens/VASP_ML20_1_best_ncdg_100/VASP_ML20_1')

# %%
print("=" * 80)
print("Train for 50 epochs with lr 0.00005")
m.compile_model(lr=0.00005, fl_alpha=0.25, fl_gamma=2.0)
m.train_model(50-33)
print("=" * 80)
print("Than train for 20 epochs with lr 0.00001")
m.compile_model(lr=0.00001, fl_alpha=0.25, fl_gamma=2.0)
m.train_model(20)
print("=" * 80)
print("Than train for 20 epochs with lr 0.000001")
m.compile_model(lr=0.00001, fl_alpha=0.25, fl_gamma=2.0)
m.train_model(20)
# Out:
# ================================================================================
# Train for 50 epochs with lr 0.00005
# Epoch 1/17
# 112/112 [==============================] - ETA: 0s - loss: 11.4311 - mse: 0.0019 - cosine_loss: 0.7169 - kl_div: 0.3478Model metrics:Recall@5=0.3363 Recall@20=0.405 Recall@50=0.5405 NCDG@100=0.4361 Coverage@5=0.0606 Coverage@20=0.1344 Coverage@50=0.2121 Coverage@100=0.2784
# New best for NCDG@100
# New best for Recall@20
# New best for Recall@50
# 112/112 [==============================] - 345s 3s/step - loss: 11.4311 - mse: 0.0019 - cosine_loss: 0.7169 - kl_div: 0.3478 - val_loss: 27.5548 - val_mse: 0.0035 - val_cosine_loss: 0.7571 - val_kl_div: 0.0000e+00
# Epoch 2/17
# 112/112 [==============================] - ETA: 0s - loss: 11.3792 - mse: 0.0019 - cosine_loss: 0.7152 - kl_div: 0.3504Model metrics:Recall@5=0.3372 Recall@20=0.4065 Recall@50=0.5437 NCDG@100=0.4372 Coverage@5=0.0651 Coverage@20=0.1438 Coverage@50=0.2231 Coverage@100=0.2937
# New best for NCDG@100
# New best for Recall@20
# New best for Recall@50
# 112/112 [==============================] - 285s 3s/step - loss: 11.3792 - mse: 0.0019 - cosine_loss: 0.7152 - kl_div: 0.3504 - val_loss: 28.1136 - val_mse: 0.0035 - val_cosine_loss: 0.7622 - val_kl_div: 0.0000e+00
# Epoch 3/17
# 112/112 [==============================] - ETA: 0s - loss: 11.3358 - mse: 0.0019 - cosine_loss: 0.7138 - kl_div: 0.3534Model metrics:Recall@5=0.3384 Recall@20=0.4073 Recall@50=0.5417 NCDG@100=0.4379 Coverage@5=0.0643 Coverage@20=0.1439 Coverage@50=0.2241 Coverage@100=0.2952
# New best for NCDG@100
# New best for Recall@20
# 112/112 [==============================] - 232s 2s/step - loss: 11.3358 - mse: 0.0019 - cosine_loss: 0.7138 - kl_div: 0.3534 - val_loss: 28.4067 - val_mse: 0.0036 - val_cosine_loss: 0.7664 - val_kl_div: 0.0000e+00
# Epoch 4/17
# 112/112 [==============================] - ETA: 0s - loss: 11.2748 - mse: 0.0019 - cosine_loss: 0.7124 - kl_div: 0.3566Model metrics:Recall@5=0.338 Recall@20=0.4066 Recall@50=0.5437 NCDG@100=0.4381 Coverage@5=0.0657 Coverage@20=0.1449 Coverage@50=0.2246 Coverage@100=0.2947
# New best for NCDG@100
# New best for Recall@50
# 112/112 [==============================] - 228s 2s/step - loss: 11.2748 - mse: 0.0019 - cosine_loss: 0.7124 - kl_div: 0.3566 - val_loss: 28.7406 - val_mse: 0.0036 - val_cosine_loss: 0.7691 - val_kl_div: 0.0000e+00
# Epoch 5/17
# 112/112 [==============================] - ETA: 0s - loss: 11.2449 - mse: 0.0019 - cosine_loss: 0.7110 - kl_div: 0.3605Model metrics:Recall@5=0.3364 Recall@20=0.4065 Recall@50=0.5421 NCDG@100=0.4372 Coverage@5=0.0697 Coverage@20=0.1533 Coverage@50=0.2337 Coverage@100=0.3061
# 112/112 [==============================] - 134s 1s/step - loss: 11.2449 - mse: 0.0019 - cosine_loss: 0.7110 - kl_div: 0.3605 - val_loss: 30.0843 - val_mse: 0.0037 - val_cosine_loss: 0.7822 - val_kl_div: 0.0000e+00
# Epoch 6/17
# 112/112 [==============================] - ETA: 0s - loss: 11.1873 - mse: 0.0018 - cosine_loss: 0.7096 - kl_div: 0.3645Model metrics:Recall@5=0.3376 Recall@20=0.4071 Recall@50=0.5428 NCDG@100=0.438 Coverage@5=0.0652 Coverage@20=0.1456 Coverage@50=0.2256 Coverage@100=0.2973
# 112/112 [==============================] - 132s 1s/step - loss: 11.1873 - mse: 0.0018 - cosine_loss: 0.7096 - kl_div: 0.3645 - val_loss: 29.3948 - val_mse: 0.0036 - val_cosine_loss: 0.7736 - val_kl_div: 0.0000e+00
# Epoch 7/17
# 112/112 [==============================] - ETA: 0s - loss: 11.1278 - mse: 0.0018 - cosine_loss: 0.7083 - kl_div: 0.3673Model metrics:Recall@5=0.3408 Recall@20=0.4081 Recall@50=0.5442 NCDG@100=0.4389 Coverage@5=0.069 Coverage@20=0.1481 Coverage@50=0.2293 Coverage@100=0.3014
# New best for NCDG@100
# New best for Recall@20
# New best for Recall@50
# 112/112 [==============================] - 284s 3s/step - loss: 11.1278 - mse: 0.0018 - cosine_loss: 0.7083 - kl_div: 0.3673 - val_loss: 29.8528 - val_mse: 0.0036 - val_cosine_loss: 0.7770 - val_kl_div: 0.0000e+00
# Epoch 8/17
# 112/112 [==============================] - ETA: 0s - loss: 11.0934 - mse: 0.0018 - cosine_loss: 0.7069 - kl_div: 0.3709Model metrics:Recall@5=0.3393 Recall@20=0.4083 Recall@50=0.5441 NCDG@100=0.438 Coverage@5=0.0678 Coverage@20=0.1518 Coverage@50=0.2333 Coverage@100=0.3064
# New best for Recall@20
# 112/112 [==============================] - 175s 2s/step - loss: 11.0934 - mse: 0.0018 - cosine_loss: 0.7069 - kl_div: 0.3709 - val_loss: 30.2454 - val_mse: 0.0036 - val_cosine_loss: 0.7789 - val_kl_div: 0.0000e+00
# Epoch 9/17
# 112/112 [==============================] - ETA: 0s - loss: 11.0477 - mse: 0.0018 - cosine_loss: 0.7054 - kl_div: 0.3744Model metrics:Recall@5=0.3383 Recall@20=0.4092 Recall@50=0.5426 NCDG@100=0.4376 Coverage@5=0.0707 Coverage@20=0.1536 Coverage@50=0.2336 Coverage@100=0.3094
# New best for Recall@20
# 112/112 [==============================] - 176s 2s/step - loss: 11.0477 - mse: 0.0018 - cosine_loss: 0.7054 - kl_div: 0.3744 - val_loss: 30.8983 - val_mse: 0.0037 - val_cosine_loss: 0.7862 - val_kl_div: 0.0000e+00
# Epoch 10/17
# 112/112 [==============================] - ETA: 0s - loss: 11.0037 - mse: 0.0018 - cosine_loss: 0.7040 - kl_div: 0.3780Model metrics:Recall@5=0.3403 Recall@20=0.4089 Recall@50=0.5459 NCDG@100=0.4379 Coverage@5=0.0732 Coverage@20=0.1579 Coverage@50=0.2406 Coverage@100=0.3149
# New best for Recall@50
# 112/112 [==============================] - 174s 2s/step - loss: 11.0037 - mse: 0.0018 - cosine_loss: 0.7040 - kl_div: 0.3780 - val_loss: 31.5644 - val_mse: 0.0037 - val_cosine_loss: 0.7915 - val_kl_div: 0.0000e+00
# Epoch 11/17
# 112/112 [==============================] - ETA: 0s - loss: 10.9501 - mse: 0.0018 - cosine_loss: 0.7028 - kl_div: 0.3811Model metrics:Recall@5=0.3409 Recall@20=0.4101 Recall@50=0.5444 NCDG@100=0.4392 Coverage@5=0.0705 Coverage@20=0.1519 Coverage@50=0.2335 Coverage@100=0.3067
# New best for NCDG@100
# New best for Recall@20
# 112/112 [==============================] - 230s 2s/step - loss: 10.9501 - mse: 0.0018 - cosine_loss: 0.7028 - kl_div: 0.3811 - val_loss: 31.2458 - val_mse: 0.0037 - val_cosine_loss: 0.7875 - val_kl_div: 0.0000e+00
# Epoch 12/17
# 112/112 [==============================] - ETA: 0s - loss: 10.9092 - mse: 0.0018 - cosine_loss: 0.7016 - kl_div: 0.3847Model metrics:Recall@5=0.3397 Recall@20=0.4102 Recall@50=0.5453 NCDG@100=0.4392 Coverage@5=0.0697 Coverage@20=0.153 Coverage@50=0.2326 Coverage@100=0.3063
# New best for Recall@20
# 112/112 [==============================] - 176s 2s/step - loss: 10.9092 - mse: 0.0018 - cosine_loss: 0.7016 - kl_div: 0.3847 - val_loss: 31.6288 - val_mse: 0.0037 - val_cosine_loss: 0.7899 - val_kl_div: 0.0000e+00
# Epoch 13/17
# 112/112 [==============================] - ETA: 0s - loss: 10.8598 - mse: 0.0018 - cosine_loss: 0.7001 - kl_div: 0.3876Model metrics:Recall@5=0.3403 Recall@20=0.4084 Recall@50=0.5448 NCDG@100=0.4394 Coverage@5=0.0716 Coverage@20=0.1565 Coverage@50=0.238 Coverage@100=0.3125
# New best for NCDG@100
# 112/112 [==============================] - 176s 2s/step - loss: 10.8598 - mse: 0.0018 - cosine_loss: 0.7001 - kl_div: 0.3876 - val_loss: 31.9752 - val_mse: 0.0037 - val_cosine_loss: 0.7920 - val_kl_div: 0.0000e+00
# Epoch 14/17
# 112/112 [==============================] - ETA: 0s - loss: 10.8210 - mse: 0.0018 - cosine_loss: 0.6988 - kl_div: 0.3912Model metrics:Recall@5=0.3394 Recall@20=0.4103 Recall@50=0.5456 NCDG@100=0.4389 Coverage@5=0.0699 Coverage@20=0.1498 Coverage@50=0.2324 Coverage@100=0.3047
# New best for Recall@20
# 112/112 [==============================] - 175s 2s/step - loss: 10.8210 - mse: 0.0018 - cosine_loss: 0.6988 - kl_div: 0.3912 - val_loss: 31.8176 - val_mse: 0.0037 - val_cosine_loss: 0.7899 - val_kl_div: 0.0000e+00
# Epoch 15/17
# 112/112 [==============================] - ETA: 0s - loss: 10.7846 - mse: 0.0018 - cosine_loss: 0.6976 - kl_div: 0.3944Model metrics:Recall@5=0.3388 Recall@20=0.4101 Recall@50=0.5455 NCDG@100=0.4381 Coverage@5=0.0743 Coverage@20=0.1599 Coverage@50=0.2436 Coverage@100=0.3158
# 112/112 [==============================] - 133s 1s/step - loss: 10.7846 - mse: 0.0018 - cosine_loss: 0.6976 - kl_div: 0.3944 - val_loss: 33.0775 - val_mse: 0.0038 - val_cosine_loss: 0.8018 - val_kl_div: 0.0000e+00
# Epoch 16/17
# 112/112 [==============================] - ETA: 0s - loss: 10.7363 - mse: 0.0018 - cosine_loss: 0.6962 - kl_div: 0.3978Model metrics:Recall@5=0.3389 Recall@20=0.4092 Recall@50=0.5463 NCDG@100=0.439 Coverage@5=0.0755 Coverage@20=0.1623 Coverage@50=0.2481 Coverage@100=0.3218
# New best for Recall@50
# 112/112 [==============================] - 174s 2s/step - loss: 10.7363 - mse: 0.0018 - cosine_loss: 0.6962 - kl_div: 0.3978 - val_loss: 33.4433 - val_mse: 0.0037 - val_cosine_loss: 0.8044 - val_kl_div: 0.0000e+00
# Epoch 17/17
# 112/112 [==============================] - ETA: 0s - loss: 10.7021 - mse: 0.0018 - cosine_loss: 0.6948 - kl_div: 0.4007Model metrics:Recall@5=0.3395 Recall@20=0.4105 Recall@50=0.5468 NCDG@100=0.4399 Coverage@5=0.0722 Coverage@20=0.1578 Coverage@50=0.2407 Coverage@100=0.3111
# New best for NCDG@100
# New best for Recall@20
# New best for Recall@50
# 112/112 [==============================] - 284s 3s/step - loss: 10.7021 - mse: 0.0018 - cosine_loss: 0.6948 - kl_div: 0.4007 - val_loss: 32.6816 - val_mse: 0.0036 - val_cosine_loss: 0.7941 - val_kl_div: 0.0000e+00
# ================================================================================
# Than train for 20 epochs with lr 0.00001
# Epoch 1/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6187 - mse: 0.0017 - cosine_loss: 0.6930 - kl_div: 0.4094Model metrics:Recall@5=0.3402 Recall@20=0.4118 Recall@50=0.5464 NCDG@100=0.4397 Coverage@5=0.0748 Coverage@20=0.1613 Coverage@50=0.245 Coverage@100=0.3167
# New best for Recall@20
# 112/112 [==============================] - 182s 2s/step - loss: 10.6187 - mse: 0.0017 - cosine_loss: 0.6930 - kl_div: 0.4094 - val_loss: 33.8017 - val_mse: 0.0038 - val_cosine_loss: 0.8060 - val_kl_div: 0.0000e+00
# Epoch 2/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6577 - mse: 0.0017 - cosine_loss: 0.6929 - kl_div: 0.4107Model metrics:Recall@5=0.3405 Recall@20=0.4118 Recall@50=0.5475 NCDG@100=0.4397 Coverage@5=0.0745 Coverage@20=0.1615 Coverage@50=0.2445 Coverage@100=0.318
# New best for Recall@20
# New best for Recall@50
# 112/112 [==============================] - 231s 2s/step - loss: 10.6577 - mse: 0.0017 - cosine_loss: 0.6929 - kl_div: 0.4107 - val_loss: 33.8164 - val_mse: 0.0038 - val_cosine_loss: 0.8062 - val_kl_div: 0.0000e+00
# Epoch 3/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6403 - mse: 0.0017 - cosine_loss: 0.6926 - kl_div: 0.4113Model metrics:Recall@5=0.34 Recall@20=0.4117 Recall@50=0.5469 NCDG@100=0.4398 Coverage@5=0.0745 Coverage@20=0.1621 Coverage@50=0.2457 Coverage@100=0.3186
# 112/112 [==============================] - 133s 1s/step - loss: 10.6403 - mse: 0.0017 - cosine_loss: 0.6926 - kl_div: 0.4113 - val_loss: 33.8926 - val_mse: 0.0037 - val_cosine_loss: 0.8065 - val_kl_div: 0.0000e+00
# Epoch 4/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6257 - mse: 0.0017 - cosine_loss: 0.6923 - kl_div: 0.4124Model metrics:Recall@5=0.3405 Recall@20=0.4111 Recall@50=0.5483 NCDG@100=0.44 Coverage@5=0.0741 Coverage@20=0.1617 Coverage@50=0.2453 Coverage@100=0.3182
# New best for NCDG@100
# New best for Recall@50
# 112/112 [==============================] - 228s 2s/step - loss: 10.6257 - mse: 0.0017 - cosine_loss: 0.6923 - kl_div: 0.4124 - val_loss: 34.0220 - val_mse: 0.0037 - val_cosine_loss: 0.8071 - val_kl_div: 0.0000e+00
# Epoch 5/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6084 - mse: 0.0017 - cosine_loss: 0.6917 - kl_div: 0.4131Model metrics:Recall@5=0.3397 Recall@20=0.412 Recall@50=0.5481 NCDG@100=0.4394 Coverage@5=0.075 Coverage@20=0.163 Coverage@50=0.2484 Coverage@100=0.3211
# New best for Recall@20
# 112/112 [==============================] - 176s 2s/step - loss: 10.6084 - mse: 0.0017 - cosine_loss: 0.6917 - kl_div: 0.4131 - val_loss: 34.1422 - val_mse: 0.0038 - val_cosine_loss: 0.8084 - val_kl_div: 0.0000e+00
# Epoch 6/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6099 - mse: 0.0017 - cosine_loss: 0.6915 - kl_div: 0.4140Model metrics:Recall@5=0.3403 Recall@20=0.4118 Recall@50=0.5478 NCDG@100=0.4398 Coverage@5=0.0742 Coverage@20=0.1618 Coverage@50=0.2458 Coverage@100=0.319
# 112/112 [==============================] - 133s 1s/step - loss: 10.6099 - mse: 0.0017 - cosine_loss: 0.6915 - kl_div: 0.4140 - val_loss: 34.1623 - val_mse: 0.0038 - val_cosine_loss: 0.8084 - val_kl_div: 0.0000e+00
# Epoch 7/20
# 112/112 [==============================] - ETA: 0s - loss: 10.6017 - mse: 0.0017 - cosine_loss: 0.6910 - kl_div: 0.4146Model metrics:Recall@5=0.3405 Recall@20=0.4123 Recall@50=0.5473 NCDG@100=0.4397 Coverage@5=0.075 Coverage@20=0.1629 Coverage@50=0.2474 Coverage@100=0.3201
# New best for Recall@20
# 112/112 [==============================] - 175s 2s/step - loss: 10.6017 - mse: 0.0017 - cosine_loss: 0.6910 - kl_div: 0.4146 - val_loss: 34.3523 - val_mse: 0.0038 - val_cosine_loss: 0.8100 - val_kl_div: 0.0000e+00
# Epoch 8/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5854 - mse: 0.0017 - cosine_loss: 0.6906 - kl_div: 0.4158Model metrics:Recall@5=0.3401 Recall@20=0.4118 Recall@50=0.5476 NCDG@100=0.4397 Coverage@5=0.075 Coverage@20=0.1627 Coverage@50=0.2479 Coverage@100=0.3208
# 112/112 [==============================] - 133s 1s/step - loss: 10.5854 - mse: 0.0017 - cosine_loss: 0.6906 - kl_div: 0.4158 - val_loss: 34.2481 - val_mse: 0.0038 - val_cosine_loss: 0.8088 - val_kl_div: 0.0000e+00
# Epoch 9/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5658 - mse: 0.0017 - cosine_loss: 0.6905 - kl_div: 0.4162Model metrics:Recall@5=0.3408 Recall@20=0.4126 Recall@50=0.5477 NCDG@100=0.4398 Coverage@5=0.0748 Coverage@20=0.1622 Coverage@50=0.2469 Coverage@100=0.32
# New best for Recall@20
# 112/112 [==============================] - 173s 2s/step - loss: 10.5658 - mse: 0.0017 - cosine_loss: 0.6905 - kl_div: 0.4162 - val_loss: 34.4340 - val_mse: 0.0038 - val_cosine_loss: 0.8104 - val_kl_div: 0.0000e+00
# Epoch 10/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5641 - mse: 0.0017 - cosine_loss: 0.6901 - kl_div: 0.4176Model metrics:Recall@5=0.3401 Recall@20=0.4124 Recall@50=0.5473 NCDG@100=0.4396 Coverage@5=0.0746 Coverage@20=0.1614 Coverage@50=0.247 Coverage@100=0.3196
# 112/112 [==============================] - 134s 1s/step - loss: 10.5641 - mse: 0.0017 - cosine_loss: 0.6901 - kl_div: 0.4176 - val_loss: 34.4828 - val_mse: 0.0038 - val_cosine_loss: 0.8103 - val_kl_div: 0.0000e+00
# Epoch 11/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5572 - mse: 0.0017 - cosine_loss: 0.6898 - kl_div: 0.4181Model metrics:Recall@5=0.3402 Recall@20=0.4116 Recall@50=0.5473 NCDG@100=0.4392 Coverage@5=0.0747 Coverage@20=0.162 Coverage@50=0.2478 Coverage@100=0.3196
# 112/112 [==============================] - 133s 1s/step - loss: 10.5572 - mse: 0.0017 - cosine_loss: 0.6898 - kl_div: 0.4181 - val_loss: 34.5598 - val_mse: 0.0038 - val_cosine_loss: 0.8109 - val_kl_div: 0.0000e+00
# Epoch 12/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5482 - mse: 0.0017 - cosine_loss: 0.6894 - kl_div: 0.4192Model metrics:Recall@5=0.3407 Recall@20=0.4127 Recall@50=0.5467 NCDG@100=0.4396 Coverage@5=0.0745 Coverage@20=0.1627 Coverage@50=0.2475 Coverage@100=0.3213
# New best for Recall@20
# 112/112 [==============================] - 174s 2s/step - loss: 10.5482 - mse: 0.0017 - cosine_loss: 0.6894 - kl_div: 0.4192 - val_loss: 34.6733 - val_mse: 0.0038 - val_cosine_loss: 0.8121 - val_kl_div: 0.0000e+00
# Epoch 13/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5421 - mse: 0.0017 - cosine_loss: 0.6891 - kl_div: 0.4202Model metrics:Recall@5=0.3406 Recall@20=0.4125 Recall@50=0.5472 NCDG@100=0.4395 Coverage@5=0.0758 Coverage@20=0.1633 Coverage@50=0.2491 Coverage@100=0.3214
# 112/112 [==============================] - 133s 1s/step - loss: 10.5421 - mse: 0.0017 - cosine_loss: 0.6891 - kl_div: 0.4202 - val_loss: 34.6627 - val_mse: 0.0038 - val_cosine_loss: 0.8115 - val_kl_div: 0.0000e+00
# Epoch 14/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5280 - mse: 0.0017 - cosine_loss: 0.6888 - kl_div: 0.4207Model metrics:Recall@5=0.3409 Recall@20=0.4121 Recall@50=0.547 NCDG@100=0.4398 Coverage@5=0.0753 Coverage@20=0.163 Coverage@50=0.2495 Coverage@100=0.323
# 112/112 [==============================] - 134s 1s/step - loss: 10.5280 - mse: 0.0017 - cosine_loss: 0.6888 - kl_div: 0.4207 - val_loss: 34.9344 - val_mse: 0.0038 - val_cosine_loss: 0.8141 - val_kl_div: 0.0000e+00
# Epoch 15/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5167 - mse: 0.0017 - cosine_loss: 0.6887 - kl_div: 0.4215Model metrics:Recall@5=0.3405 Recall@20=0.4128 Recall@50=0.5469 NCDG@100=0.4395 Coverage@5=0.0755 Coverage@20=0.1637 Coverage@50=0.2497 Coverage@100=0.3228
# New best for Recall@20
# 112/112 [==============================] - 176s 2s/step - loss: 10.5167 - mse: 0.0017 - cosine_loss: 0.6887 - kl_div: 0.4215 - val_loss: 34.9510 - val_mse: 0.0038 - val_cosine_loss: 0.8143 - val_kl_div: 0.0000e+00
# Epoch 16/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5081 - mse: 0.0017 - cosine_loss: 0.6883 - kl_div: 0.4219Model metrics:Recall@5=0.3404 Recall@20=0.4128 Recall@50=0.5479 NCDG@100=0.4397 Coverage@5=0.075 Coverage@20=0.1634 Coverage@50=0.249 Coverage@100=0.3228
# New best for Recall@20
# 112/112 [==============================] - 174s 2s/step - loss: 10.5081 - mse: 0.0017 - cosine_loss: 0.6883 - kl_div: 0.4219 - val_loss: 34.9948 - val_mse: 0.0038 - val_cosine_loss: 0.8139 - val_kl_div: 0.0000e+00
# Epoch 17/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5099 - mse: 0.0017 - cosine_loss: 0.6880 - kl_div: 0.4231Model metrics:Recall@5=0.3397 Recall@20=0.4124 Recall@50=0.5467 NCDG@100=0.4396 Coverage@5=0.0764 Coverage@20=0.1639 Coverage@50=0.2501 Coverage@100=0.3236
# 112/112 [==============================] - 134s 1s/step - loss: 10.5099 - mse: 0.0017 - cosine_loss: 0.6880 - kl_div: 0.4231 - val_loss: 35.1209 - val_mse: 0.0038 - val_cosine_loss: 0.8153 - val_kl_div: 0.0000e+00
# Epoch 18/20
# 112/112 [==============================] - ETA: 0s - loss: 10.5010 - mse: 0.0017 - cosine_loss: 0.6878 - kl_div: 0.4237Model metrics:Recall@5=0.34 Recall@20=0.4115 Recall@50=0.548 NCDG@100=0.4393 Coverage@5=0.0749 Coverage@20=0.1638 Coverage@50=0.2478 Coverage@100=0.3218
# 112/112 [==============================] - 134s 1s/step - loss: 10.5010 - mse: 0.0017 - cosine_loss: 0.6878 - kl_div: 0.4237 - val_loss: 35.1436 - val_mse: 0.0038 - val_cosine_loss: 0.8155 - val_kl_div: 0.0000e+00
# Epoch 19/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4910 - mse: 0.0017 - cosine_loss: 0.6875 - kl_div: 0.4246Model metrics:Recall@5=0.3399 Recall@20=0.4122 Recall@50=0.5473 NCDG@100=0.4395 Coverage@5=0.077 Coverage@20=0.1644 Coverage@50=0.2487 Coverage@100=0.3223
# 112/112 [==============================] - 133s 1s/step - loss: 10.4910 - mse: 0.0017 - cosine_loss: 0.6875 - kl_div: 0.4246 - val_loss: 35.2602 - val_mse: 0.0038 - val_cosine_loss: 0.8162 - val_kl_div: 0.0000e+00
# Epoch 20/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4720 - mse: 0.0017 - cosine_loss: 0.6870 - kl_div: 0.4250Model metrics:Recall@5=0.3397 Recall@20=0.4119 Recall@50=0.5471 NCDG@100=0.4393 Coverage@5=0.0755 Coverage@20=0.1644 Coverage@50=0.2496 Coverage@100=0.3235
# 112/112 [==============================] - 133s 1s/step - loss: 10.4720 - mse: 0.0017 - cosine_loss: 0.6870 - kl_div: 0.4250 - val_loss: 35.3142 - val_mse: 0.0038 - val_cosine_loss: 0.8167 - val_kl_div: 0.0000e+00
# ================================================================================
# Than train for 20 epochs with lr 0.000001
# Epoch 1/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4702 - mse: 0.0017 - cosine_loss: 0.6868 - kl_div: 0.4259Model metrics:Recall@5=0.3398 Recall@20=0.4129 Recall@50=0.5481 NCDG@100=0.4395 Coverage@5=0.0764 Coverage@20=0.1644 Coverage@50=0.2484 Coverage@100=0.3201
# New best for Recall@20
# 112/112 [==============================] - 183s 2s/step - loss: 10.4702 - mse: 0.0017 - cosine_loss: 0.6868 - kl_div: 0.4259 - val_loss: 35.4194 - val_mse: 0.0038 - val_cosine_loss: 0.8167 - val_kl_div: 0.0000e+00
# Epoch 2/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4444 - mse: 0.0017 - cosine_loss: 0.6865 - kl_div: 0.4263Model metrics:Recall@5=0.3392 Recall@20=0.412 Recall@50=0.5474 NCDG@100=0.4394 Coverage@5=0.0762 Coverage@20=0.1628 Coverage@50=0.2484 Coverage@100=0.3203
# 112/112 [==============================] - 134s 1s/step - loss: 10.4444 - mse: 0.0017 - cosine_loss: 0.6865 - kl_div: 0.4263 - val_loss: 35.2966 - val_mse: 0.0038 - val_cosine_loss: 0.8153 - val_kl_div: 0.0000e+00
# Epoch 3/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4545 - mse: 0.0017 - cosine_loss: 0.6861 - kl_div: 0.4272Model metrics:Recall@5=0.3393 Recall@20=0.4122 Recall@50=0.5473 NCDG@100=0.4396 Coverage@5=0.0769 Coverage@20=0.1644 Coverage@50=0.2482 Coverage@100=0.3221
# 112/112 [==============================] - 133s 1s/step - loss: 10.4545 - mse: 0.0017 - cosine_loss: 0.6861 - kl_div: 0.4272 - val_loss: 35.5332 - val_mse: 0.0038 - val_cosine_loss: 0.8172 - val_kl_div: 0.0000e+00
# Epoch 4/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4346 - mse: 0.0017 - cosine_loss: 0.6859 - kl_div: 0.4282Model metrics:Recall@5=0.339 Recall@20=0.4117 Recall@50=0.5468 NCDG@100=0.4392 Coverage@5=0.0761 Coverage@20=0.1639 Coverage@50=0.2488 Coverage@100=0.322
# 112/112 [==============================] - 133s 1s/step - loss: 10.4346 - mse: 0.0017 - cosine_loss: 0.6859 - kl_div: 0.4282 - val_loss: 35.6003 - val_mse: 0.0038 - val_cosine_loss: 0.8184 - val_kl_div: 0.0000e+00
# Epoch 5/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4351 - mse: 0.0017 - cosine_loss: 0.6857 - kl_div: 0.4287Model metrics:Recall@5=0.3387 Recall@20=0.4116 Recall@50=0.5473 NCDG@100=0.4388 Coverage@5=0.0771 Coverage@20=0.1661 Coverage@50=0.2506 Coverage@100=0.3238
# 112/112 [==============================] - 133s 1s/step - loss: 10.4351 - mse: 0.0017 - cosine_loss: 0.6857 - kl_div: 0.4287 - val_loss: 35.7924 - val_mse: 0.0038 - val_cosine_loss: 0.8195 - val_kl_div: 0.0000e+00
# Epoch 6/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4284 - mse: 0.0017 - cosine_loss: 0.6853 - kl_div: 0.4294Model metrics:Recall@5=0.34 Recall@20=0.4119 Recall@50=0.547 NCDG@100=0.4393 Coverage@5=0.0769 Coverage@20=0.1655 Coverage@50=0.2501 Coverage@100=0.3238
# 112/112 [==============================] - 133s 1s/step - loss: 10.4284 - mse: 0.0017 - cosine_loss: 0.6853 - kl_div: 0.4294 - val_loss: 35.6913 - val_mse: 0.0038 - val_cosine_loss: 0.8183 - val_kl_div: 0.0000e+00
# Epoch 7/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4235 - mse: 0.0017 - cosine_loss: 0.6851 - kl_div: 0.4304Model metrics:Recall@5=0.3393 Recall@20=0.4116 Recall@50=0.5473 NCDG@100=0.4392 Coverage@5=0.077 Coverage@20=0.1657 Coverage@50=0.2516 Coverage@100=0.3251
# 112/112 [==============================] - 133s 1s/step - loss: 10.4235 - mse: 0.0017 - cosine_loss: 0.6851 - kl_div: 0.4304 - val_loss: 35.7226 - val_mse: 0.0038 - val_cosine_loss: 0.8184 - val_kl_div: 0.0000e+00
# Epoch 8/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4131 - mse: 0.0017 - cosine_loss: 0.6847 - kl_div: 0.4310Model metrics:Recall@5=0.3394 Recall@20=0.4119 Recall@50=0.546 NCDG@100=0.4393 Coverage@5=0.0774 Coverage@20=0.1653 Coverage@50=0.2501 Coverage@100=0.3246
# 112/112 [==============================] - 133s 1s/step - loss: 10.4131 - mse: 0.0017 - cosine_loss: 0.6847 - kl_div: 0.4310 - val_loss: 35.9212 - val_mse: 0.0038 - val_cosine_loss: 0.8201 - val_kl_div: 0.0000e+00
# Epoch 9/20
# 112/112 [==============================] - ETA: 0s - loss: 10.4015 - mse: 0.0017 - cosine_loss: 0.6846 - kl_div: 0.4313Model metrics:Recall@5=0.3384 Recall@20=0.4117 Recall@50=0.5466 NCDG@100=0.4392 Coverage@5=0.0778 Coverage@20=0.1657 Coverage@50=0.2501 Coverage@100=0.3236
# 112/112 [==============================] - 134s 1s/step - loss: 10.4015 - mse: 0.0017 - cosine_loss: 0.6846 - kl_div: 0.4313 - val_loss: 35.9395 - val_mse: 0.0038 - val_cosine_loss: 0.8199 - val_kl_div: 0.0000e+00
# Epoch 10/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3937 - mse: 0.0017 - cosine_loss: 0.6842 - kl_div: 0.4326Model metrics:Recall@5=0.3391 Recall@20=0.4116 Recall@50=0.5467 NCDG@100=0.4393 Coverage@5=0.0773 Coverage@20=0.1646 Coverage@50=0.2506 Coverage@100=0.3243
# 112/112 [==============================] - 133s 1s/step - loss: 10.3937 - mse: 0.0017 - cosine_loss: 0.6842 - kl_div: 0.4326 - val_loss: 35.9471 - val_mse: 0.0038 - val_cosine_loss: 0.8194 - val_kl_div: 0.0000e+00
# Epoch 11/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3869 - mse: 0.0017 - cosine_loss: 0.6839 - kl_div: 0.4331Model metrics:Recall@5=0.3394 Recall@20=0.4123 Recall@50=0.5461 NCDG@100=0.4395 Coverage@5=0.0773 Coverage@20=0.1652 Coverage@50=0.2512 Coverage@100=0.3244
# 112/112 [==============================] - 133s 1s/step - loss: 10.3869 - mse: 0.0017 - cosine_loss: 0.6839 - kl_div: 0.4331 - val_loss: 36.0308 - val_mse: 0.0038 - val_cosine_loss: 0.8202 - val_kl_div: 0.0000e+00
# Epoch 12/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3690 - mse: 0.0017 - cosine_loss: 0.6836 - kl_div: 0.4335Model metrics:Recall@5=0.339 Recall@20=0.4112 Recall@50=0.5465 NCDG@100=0.439 Coverage@5=0.0781 Coverage@20=0.1663 Coverage@50=0.2529 Coverage@100=0.3258
# 112/112 [==============================] - 133s 1s/step - loss: 10.3690 - mse: 0.0017 - cosine_loss: 0.6836 - kl_div: 0.4335 - val_loss: 36.1371 - val_mse: 0.0038 - val_cosine_loss: 0.8216 - val_kl_div: 0.0000e+00
# Epoch 13/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3606 - mse: 0.0017 - cosine_loss: 0.6834 - kl_div: 0.4345Model metrics:Recall@5=0.3391 Recall@20=0.4112 Recall@50=0.5474 NCDG@100=0.4391 Coverage@5=0.0779 Coverage@20=0.1666 Coverage@50=0.2512 Coverage@100=0.3249
# 112/112 [==============================] - 133s 1s/step - loss: 10.3606 - mse: 0.0017 - cosine_loss: 0.6834 - kl_div: 0.4345 - val_loss: 36.1235 - val_mse: 0.0038 - val_cosine_loss: 0.8213 - val_kl_div: 0.0000e+00
# Epoch 14/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3459 - mse: 0.0017 - cosine_loss: 0.6831 - kl_div: 0.4346Model metrics:Recall@5=0.3386 Recall@20=0.4109 Recall@50=0.5464 NCDG@100=0.439 Coverage@5=0.0781 Coverage@20=0.167 Coverage@50=0.2525 Coverage@100=0.3261
# 112/112 [==============================] - 133s 1s/step - loss: 10.3459 - mse: 0.0017 - cosine_loss: 0.6831 - kl_div: 0.4346 - val_loss: 36.2812 - val_mse: 0.0038 - val_cosine_loss: 0.8223 - val_kl_div: 0.0000e+00
# Epoch 15/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3511 - mse: 0.0017 - cosine_loss: 0.6827 - kl_div: 0.4359Model metrics:Recall@5=0.3392 Recall@20=0.4115 Recall@50=0.5463 NCDG@100=0.4395 Coverage@5=0.0779 Coverage@20=0.1655 Coverage@50=0.252 Coverage@100=0.3255
# 112/112 [==============================] - 134s 1s/step - loss: 10.3511 - mse: 0.0017 - cosine_loss: 0.6827 - kl_div: 0.4359 - val_loss: 36.2337 - val_mse: 0.0038 - val_cosine_loss: 0.8213 - val_kl_div: 0.0000e+00
# Epoch 16/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3317 - mse: 0.0017 - cosine_loss: 0.6825 - kl_div: 0.4364Model metrics:Recall@5=0.3382 Recall@20=0.411 Recall@50=0.5462 NCDG@100=0.4387 Coverage@5=0.0783 Coverage@20=0.1656 Coverage@50=0.2524 Coverage@100=0.3251
# 112/112 [==============================] - 133s 1s/step - loss: 10.3317 - mse: 0.0017 - cosine_loss: 0.6825 - kl_div: 0.4364 - val_loss: 36.4754 - val_mse: 0.0038 - val_cosine_loss: 0.8234 - val_kl_div: 0.0000e+00
# Epoch 17/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3447 - mse: 0.0017 - cosine_loss: 0.6822 - kl_div: 0.4371Model metrics:Recall@5=0.3388 Recall@20=0.4113 Recall@50=0.5458 NCDG@100=0.4391 Coverage@5=0.0774 Coverage@20=0.1659 Coverage@50=0.2522 Coverage@100=0.3254
# 112/112 [==============================] - 134s 1s/step - loss: 10.3447 - mse: 0.0017 - cosine_loss: 0.6822 - kl_div: 0.4371 - val_loss: 36.3856 - val_mse: 0.0038 - val_cosine_loss: 0.8223 - val_kl_div: 0.0000e+00
# Epoch 18/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3180 - mse: 0.0017 - cosine_loss: 0.6819 - kl_div: 0.4372Model metrics:Recall@5=0.3377 Recall@20=0.4115 Recall@50=0.5462 NCDG@100=0.4386 Coverage@5=0.0779 Coverage@20=0.1672 Coverage@50=0.2541 Coverage@100=0.326
# 112/112 [==============================] - 133s 1s/step - loss: 10.3180 - mse: 0.0017 - cosine_loss: 0.6819 - kl_div: 0.4372 - val_loss: 36.6292 - val_mse: 0.0038 - val_cosine_loss: 0.8246 - val_kl_div: 0.0000e+00
# Epoch 19/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3126 - mse: 0.0017 - cosine_loss: 0.6818 - kl_div: 0.4382Model metrics:Recall@5=0.3394 Recall@20=0.4113 Recall@50=0.5466 NCDG@100=0.4388 Coverage@5=0.0785 Coverage@20=0.1669 Coverage@50=0.2544 Coverage@100=0.3262
# 112/112 [==============================] - 134s 1s/step - loss: 10.3126 - mse: 0.0017 - cosine_loss: 0.6818 - kl_div: 0.4382 - val_loss: 36.5689 - val_mse: 0.0038 - val_cosine_loss: 0.8240 - val_kl_div: 0.0000e+00
# Epoch 20/20
# 112/112 [==============================] - ETA: 0s - loss: 10.3061 - mse: 0.0017 - cosine_loss: 0.6815 - kl_div: 0.4390Model metrics:Recall@5=0.3393 Recall@20=0.4118 Recall@50=0.5471 NCDG@100=0.4388 Coverage@5=0.0784 Coverage@20=0.1666 Coverage@50=0.253 Coverage@100=0.3258
# 112/112 [==============================] - 133s 1s/step - loss: 10.3061 - mse: 0.0017 - cosine_loss: 0.6815 - kl_div: 0.4390 - val_loss: 36.5164 - val_mse: 0.0038 - val_cosine_loss: 0.8234 - val_kl_div: 0.0000e+00

# %%
# m.model.load_weights("/content/drive/MyDrive/RS/VASP_ML20_1_best_recall_50/VASP_ML20_1")

# %%
x,y = dataset.split.validation_gen.__getitem__(2)

# %%
x.shape,y.shape
# Out:
# ((128, 20721), (128, 20721))

# %%
m.model.output_shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-cb297059ffe7> in <module>()
# ----> 1 m.model.output_shape
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in output_shape(self)
#    2226     """
#    2227     if not self._inbound_nodes:
# -> 2228       raise AttributeError(f'The layer "{self.name}" has never been called '
#    2229                            'and thus has no defined output shape.')
#    2230     all_output_shapes = set(
#
# AttributeError: The layer "model" has never been called and thus has no defined output shape.

# %% [markdown]
# Dataframe with the details of the training.

# %%
m.mc.get_history_df()

# %% [markdown]
# And the details of the training as a plot.

# %%
m.mc.plot_history()

# %% [markdown]
# For final evaluation we do 5-fold validation on the user's interaction history. We think that this is more objective measure than only hide sampled 20% of the user's interactions randomly.

# %%
# 5-fold evaluation on the test set

# test_r20s = []
# test_r50s = []
# test_n100s = []

# for fold in range(1,6):
#     ev=Evaluator(m.split, method=str(fold)+'_20')
#     ev.update(m.model)

#     test_n100s.append(ev.get_ncdg(100))
#     test_r20s.append(ev.get_recall(20))
#     test_r50s.append(ev.get_recall(50))

# print("TEST SET (MEAN)")
# print("5-fold mean NCDG@100", round(sum(test_n100s) / len(test_n100s),3))
# print("5-fold mean Recall@20", round(sum(test_r20s) / len(test_r20s),3))
# print("5-fold mean Recall@50", round(sum(test_r50s) / len(test_r50s),3))

# %%
! cp /content/VASP_ML20_1_best_recall_*   /content/drive/MyDrive/RS -r

# %% [markdown]
# # Inference

# %%
import tensorflow as tf

class DiagonalToZero(tf.keras.constraints.Constraint):
    def __call__(self, w):
        """Set diagonal to zero"""
        q = tf.linalg.set_diag(w, tf.zeros(w.shape[0:-1]), name=None)
        return q

class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a basket."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim), stddev=1.)
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


class VASP(tf.keras.Model):
    def __init__(self, num_words, latent=1024, hidden=1024, items_sampling=1.):
        """
        num_words             nr of items in dataset (size of tokenizer)
        latent                size of latent space
        hidden                size of hidden layers
        items_sampling        Large items datatsets can be very gpu memory consuming in EASE layer.
                              This coefficient reduces number of ease parametrs by taking only
                              fraction of items sorted by popularity as input for model.
                              Note: This coef should be somewhere around coverage@100 achieved by full
                              size model.
                              For ML20M this coef should be between 0.4888 (coverage@100 for full model)
                              and 1.0
                              For Netflix this coef should be between 0.7055 (coverage@100 for full
                              model) and 1.0
        """
        # super(tf.keras.Model, self).__init__()
        super().__init__()
        self.num_words = num_words
        self.sampled_items = int(num_words * items_sampling)

        assert self.sampled_items > 0
        assert self.sampled_items <= num_words

        self.s = self.sampled_items < num_words

        # ************* ENCODER ***********************
        self.encoder1 = tf.keras.layers.Dense(hidden)
        self.ln1 = tf.keras.layers.LayerNormalization()
        self.encoder2 = tf.keras.layers.Dense(hidden)
        self.ln2 = tf.keras.layers.LayerNormalization()
        self.encoder3 = tf.keras.layers.Dense(hidden)
        self.ln3 = tf.keras.layers.LayerNormalization()
        self.encoder4 = tf.keras.layers.Dense(hidden)
        self.ln4 = tf.keras.layers.LayerNormalization()
        self.encoder5 = tf.keras.layers.Dense(hidden)
        self.ln5 = tf.keras.layers.LayerNormalization()
        self.encoder6 = tf.keras.layers.Dense(hidden)
        self.ln6 = tf.keras.layers.LayerNormalization()
        self.encoder7 = tf.keras.layers.Dense(hidden)
        self.ln7 = tf.keras.layers.LayerNormalization()

        # ************* SAMPLING **********************
        self.dense_mean = tf.keras.layers.Dense(latent,
                                                name="Mean")
        self.dense_log_var = tf.keras.layers.Dense(latent,
                                                    name="log_var")

        self.sampling = Sampling(name='Sampler')

        # ************* DECODER ***********************
        self.decoder1 = tf.keras.layers.Dense(hidden)
        self.dln1 = tf.keras.layers.LayerNormalization()
        self.decoder2 = tf.keras.layers.Dense(hidden)
        self.dln2 = tf.keras.layers.LayerNormalization()
        self.decoder3 = tf.keras.layers.Dense(hidden)
        self.dln3 = tf.keras.layers.LayerNormalization()
        self.decoder4 = tf.keras.layers.Dense(hidden)
        self.dln4 = tf.keras.layers.LayerNormalization()
        self.decoder5 = tf.keras.layers.Dense(hidden)
        self.dln5 = tf.keras.layers.LayerNormalization()

        self.decoder_resnet = tf.keras.layers.Dense(self.sampled_items,
                                                    activation='sigmoid',
                                                    name="DecoderR")
        self.decoder_latent = tf.keras.layers.Dense(self.sampled_items,
                                                    activation='sigmoid',
                                                    name="DecoderL")

        # ************* PARALLEL SHALLOW PATH *********

        self.ease = tf.keras.layers.Dense(
            self.sampled_items,
            activation='sigmoid',
            use_bias=False,
            kernel_constraint=DiagonalToZero(),  # critical to prevent learning simple identity
        )

    def call(self, x, training=None):
        sampling = self.s
        if sampling:
            sampled_x = x[:, :self.sampled_items]
            non_sampled = x[:, self.sampled_items:] * 0.
        else:
            sampled_x = x

        z_mean, z_log_var, z = self.encode(sampled_x)
        if training:
            d = self.decode(z)
            # Add KL divergence regularization loss.
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_mean(kl_loss)
            kl_loss *= -0.5
            self.add_loss(kl_loss)
            self.add_metric(kl_loss, name="kl_div")
        else:
            d = self.decode(z_mean)

        if sampling:
            d = tf.concat([d, non_sampled], axis=-1)

        ease = self.ease(sampled_x)

        if sampling:
            ease = tf.concat([ease, non_sampled], axis=-1)

        return d * ease

    def decode(self, x):
        e0 = x
        e1 = self.dln1(tf.keras.activations.swish(self.decoder1(e0)))
        e2 = self.dln2(tf.keras.activations.swish(self.decoder2(e1) + e1))
        e3 = self.dln3(tf.keras.activations.swish(self.decoder3(e2) + e1 + e2))
        e4 = self.dln4(tf.keras.activations.swish(self.decoder4(e3) + e1 + e2 + e3))
        e5 = self.dln5(tf.keras.activations.swish(self.decoder5(e4) + e1 + e2 + e3 + e4))

        dr = self.decoder_resnet(e5)
        dl = self.decoder_latent(x)

        return dr * dl

    def encode(self, x):
        e0 = x
        e1 = self.ln1(tf.keras.activations.swish(self.encoder1(e0)))
        e2 = self.ln2(tf.keras.activations.swish(self.encoder2(e1) + e1))
        e3 = self.ln3(tf.keras.activations.swish(self.encoder3(e2) + e1 + e2))
        e4 = self.ln4(tf.keras.activations.swish(self.encoder4(e3) + e1 + e2 + e3))
        e5 = self.ln5(tf.keras.activations.swish(self.encoder5(e4) + e1 + e2 + e3 + e4))
        e6 = self.ln6(tf.keras.activations.swish(self.encoder6(e5) + e1 + e2 + e3 + e4 + e5))
        e7 = self.ln7(tf.keras.activations.swish(self.encoder7(e6) + e1 + e2 + e3 + e4 + e5 + e6))

        z_mean = self.dense_mean(e7)
        z_log_var = self.dense_log_var(e7)
        z = self.sampling((z_mean, z_log_var))

        return z_mean, z_log_var, z

# def create_model(num_words, latent=2048, hidden=4096, ease_items_sampling=1., summary=False):
# num_words = 14409
# model = VASP(num_words, latent, hidden, ease_items_sampling)
# # model(self.split.train_gen[0][0])



# m = VASP()
model = VASP(num_words = 14409, latent=2048, hidden=4096,items_sampling =0.33)
model.load_weights("/content/drive/MyDrive/RS/VASP_ML20_1_best_recall_50/VASP_ML20_1")

# %%
import numpy as np
e = np.random.choice([0,1],size =14409 ).reshape(1,-1)

# %%
p = model.call(e)
# model.summary()
p

# %%
p.shape

# %%
p[0].numpy()

# %%
import tensorflow as tf
toki = tf.keras.preprocessing.text.Tokenizer()

# %%
toki.fit_on_texts("A B C D".split())

# %%
toki.texts_to_matrix('A')

# %%
# !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
